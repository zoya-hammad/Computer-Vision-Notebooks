# %% [markdown]
# # **Color Spaces**
#
# 1. View the individual channels of an RGB Image
# 2. Manipulate a color space
# 3. Introduce HSV Color Space

# %%
# Our Setup, Import Libaries, Create our Imshow Function
import cv2
import numpy as np
from matplotlib import pyplot as plt

# Define our imshow function
def imshow(title = "Image", image = None, size = 10):
    w, h = image.shape[0], image.shape[1]
    aspect_ratio = w/h
    plt.figure(figsize=(size * aspect_ratio,size))
    plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
    plt.title(title)
    plt.show()

# %%
# Load our input image
image = cv2.imread('nature.jpeg')

# Use cv2.split to get each color space separately
B, G, R = cv2.split(image)
print(B.shape)
print(G.shape)
print(R.shape)
# Out:
# (177, 284)
# (177, 284)
# (177, 284)

# %%
# Each color space on it's on will look like a grayscale as it lacks the other color channels
imshow("Red Channel Only", R)

# %%
import numpy as np

zeros = np.zeros(image.shape[:2],dtype="uint8")

# creates a black (zero-valued) grayscale image of the same size as the original image.
# we only take the dimensions of the image, not the color channels.
# Always specify dtype="uint8" when working with OpenCV images.OpenCV expects images to have pixel values in the range 0-255 (8-bit unsigned integer format).

# %%
# To display only one color, we need to set the other two channels to zero (completely black). This is called masking out the other channels.
imshow("Red", cv2.merge([zeros, zeros, R]))
imshow("Green", cv2.merge([zeros, G, zeros]))
imshow("Blue", cv2.merge([B, zeros, zeros]))

# The order for cv2.merge is [Blue, Green, Red].

# %%
image = cv2.imread('nature.jpeg')

# OpenCV's 'split' function splites the image into each color index
B, G, R = cv2.split(image)

# Let's re-make the original image,
merged = cv2.merge([B, G, R])
imshow("Merged", merged)

# %%
# Let's amplify the blue color
merged = cv2.merge([B+100, G, R])
imshow("Blue Boost", merged)

# %%
# Custom Boost
merged = cv2.merge([B+2, G, R+2])
imshow("Custom Boost", merged)

# %% [markdown]
# ## **The HSV Color Space**
#
# ![](https://upload.wikimedia.org/wikipedia/commons/f/f2/HSV_color_solid_cone.png)
#
# - Hue: 0 - 179 color map
# - Saturation: 0 - 255  faded/richer
# - Value (Intensity): 0 - 255  brightness

# %%
# Reload our image
image = cv2.imread('nature.jpeg')

# Convert to HSV
hsv_image = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)
imshow('HSV', hsv_image)

# %% [markdown]
# This looks odd because our plotting function was designed for RGB only images, not HSV

# %%
plt.imshow(cv2.cvtColor(hsv_image, cv2.COLOR_HSV2RGB))
plt.show()

# %% [markdown]
# ### **Let's view each channel type in the HSV Color Space representation**

# %%
# Switching back to viewing the RGB representation
imshow("Hue", hsv_image[:, :, 0])
imshow("Saturation", hsv_image[:, :, 1])
imshow("Value", hsv_image[:, :, 2])
